# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
divorce_df = pd.read_csv("divorce.csv")
divorce_df
# Out:
#     Unnamed: 0  year        date  all_3544   HS_3544   SC_3544  BAp_3544  \
# 0            1  1960  1960-01-01  0.034445  0.034889  0.033669  0.027513
# 1            2  1970  1970-01-01  0.049256  0.050000  0.048705  0.041259
# 2            3  1980  1980-01-01  0.106005  0.104151  0.112699  0.097772
# 3            4  1990  1990-01-01  0.150805  0.159381  0.169670  0.114955
# 4            5  2000  2000-01-01  0.156841  0.175446  0.173803  0.105618
# 5            6  2001  2001-01-01  0.157306  0.174116  0.178169  0.107039
# 6            7  2002  2002-01-01  0.156508  0.174769  0.179294  0.103442
# 7            8  2003  2003-01-01  0.153844  0.172545  0.176975  0.102550
# 8            9  2004  2004-01-01  0.154841  0.177565  0.177080  0.100337
# 9           10  2005  2005-01-01  0.152920  0.175164  0.176743  0.099481
# 10          11  2006  2006-01-01  0.161890  0.189437  0.184121  0.103835
# 11          12  2007  2007-01-01  0.160469  0.187216  0.184961  0.103929
# ...

# %%
#divorce_df.dropna()
divorce_df.fillna(0)
# Out:
#     Unnamed: 0  year        date  all_3544   HS_3544   SC_3544  BAp_3544  \
# 0            1  1960  1960-01-01  0.034445  0.034889  0.033669  0.027513
# 1            2  1970  1970-01-01  0.049256  0.050000  0.048705  0.041259
# 2            3  1980  1980-01-01  0.106005  0.104151  0.112699  0.097772
# 3            4  1990  1990-01-01  0.150805  0.159381  0.169670  0.114955
# 4            5  2000  2000-01-01  0.156841  0.175446  0.173803  0.105618
# 5            6  2001  2001-01-01  0.157306  0.174116  0.178169  0.107039
# 6            7  2002  2002-01-01  0.156508  0.174769  0.179294  0.103442
# 7            8  2003  2003-01-01  0.153844  0.172545  0.176975  0.102550
# 8            9  2004  2004-01-01  0.154841  0.177565  0.177080  0.100337
# 9           10  2005  2005-01-01  0.152920  0.175164  0.176743  0.099481
# 10          11  2006  2006-01-01  0.161890  0.189437  0.184121  0.103835
# 11          12  2007  2007-01-01  0.160469  0.187216  0.184961  0.103929
# ...

# %%
# Calculating Percentage
divorce_df['SC_3544'] = divorce_df['SC_3544'] * 100
divorce_df['GD_3544'] = divorce_df['GD_3544'] * 100
divorce_df['HS_3544'] = divorce_df['HS_3544'] * 100
#Merging 2 columns before converting into percentage
#divorce_df['highSchoolorLow'] = divorce_df['HS_3544'] + divorce_df['HS_4554']
#divorce_df['highSchoolorLow'] = divorce_df['highSchoolorLow'] * 100

#Merging 2 columns before converting into percentage 
# divorce_df['CollegeGrads'] = divorce_df['GD_3544'] + divorce_df['GD_4554']
# divorce_df['CollegeGrads'] = divorce_df['CollegeGrads'] * 100
divorce_df
# Out:
#     Unnamed: 0  year        date  all_3544    HS_3544    SC_3544  BAp_3544  \
# 0            1  1960  1960-01-01  0.034445   3.488887   3.366938  0.027513
# 1            2  1970  1970-01-01  0.049256   4.999984   4.870549  0.041259
# 2            3  1980  1980-01-01  0.106005  10.415128  11.269947  0.097772
# 3            4  1990  1990-01-01  0.150805  15.938095  16.967005  0.114955
# 4            5  2000  2000-01-01  0.156841  17.544616  17.380324  0.105618
# 5            6  2001  2001-01-01  0.157306  17.411604  17.816906  0.107039
# 6            7  2002  2002-01-01  0.156508  17.476931  17.929419  0.103442
# 7            8  2003  2003-01-01  0.153844  17.254483  17.697536  0.102550
# 8            9  2004  2004-01-01  0.154841  17.756455  17.707955  0.100337
# 9           10  2005  2005-01-01  0.152920  17.516353  17.674265  0.099481
# 10          11  2006  2006-01-01  0.161890  18.943673  18.412098  0.103835
# ...

# %%
divorce_df.isna().sum()
# Out:
# Unnamed: 0    0
# year          0
# date          0
# all_3544      0
# HS_3544       0
# SC_3544       0
# BAp_3544      0
# BAo_3544      0
# GD_3544       3
# poor_3544     0
# mid_3544      0
# rich_3544     0
# all_4554      0
# HS_4554       0
# SC_4554       0
# BAp_4554      0
# BAo_4554      0
# GD_4554       3
# poor_4554     0
# mid_4554      0
# rich_4554     0
# dtype: int64

# %%
fig, ax = plt.subplots()
ax.plot(divorce_df['year'], divorce_df['SC_3544'])
ax.plot(divorce_df['year'], divorce_df['GD_3544'])
ax.plot(divorce_df['year'], divorce_df['HS_3544'])
# ax.set_ylim(5,25)
plt.title('Divorce Rates by Education')
plt.xlabel('Year')
plt.ylabel('Percentage of divorce')
plt.show()
